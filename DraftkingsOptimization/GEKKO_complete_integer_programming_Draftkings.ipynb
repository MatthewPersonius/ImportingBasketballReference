# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import array
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import train_test_split 
from sklearn import linear_model, preprocessing 
import warnings
import statsmodels.api as sm
# !pip install GEKKO
# !pip install ortools

from gekko import GEKKO
# Out:
# Requirement already satisfied: GEKKO in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from GEKKO) (1.20.1)
# Requirement already satisfied: ortools in /opt/anaconda3/lib/python3.8/site-packages (9.0.9048)
# Requirement already satisfied: protobuf>=3.15.8 in /opt/anaconda3/lib/python3.8/site-packages (from ortools) (3.18.0)
# Requirement already satisfied: absl-py>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from ortools) (0.14.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from absl-py>=0.11->ortools) (1.15.0)

# %%
Download=pd.read_csv("DKSalaries-4.csv")

# %%
#Download = Download.reset_index()

Download.index = np.arange(1, len(Download)+1)

# %%
Download
# Out:
#     Position                       Name + ID                 Name        ID  \
# 1         RB  Christian McCaffrey (19289790)  Christian McCaffrey  19289790
# 2         QB          Sam Darnold (19289791)          Sam Darnold  19289791
# 3         WR             DJ Moore (19289792)             DJ Moore  19289792
# 4         WR        Brandin Cooks (19289793)        Brandin Cooks  19289793
# 5         QB         Tyrod Taylor (19289794)         Tyrod Taylor  19289794
# ..       ...                             ...                  ...       ...
# 100       WR          Chris Moore (19289785)          Chris Moore  19289785
# 101       TE        Brevin Jordan (19289786)        Brevin Jordan  19289786
# 102       RB        Spencer Brown (19289787)        Spencer Brown  19289787
# 103       WR           Jalen Camp (19289788)           Jalen Camp  19289788
# 104       WR         Jordan Veasy (19289789)         Jordan Veasy  19289789
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 1               CPT   20100  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 2               CPT   16800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 3               CPT   15900  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 4               CPT   15000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 5               CPT   14700  CAR@HOU 09/23/2021 08:20PM ET        HOU
# ..              ...     ...                            ...        ...
# 100            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 101            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 102            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 103            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 104            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
#
#      AvgPointsPerGame
# 1               26.20
# 2               21.48
# 3               18.65
# 4               22.00
# 5               20.07
# ..                ...
# 100              0.00
# 101              0.00
# 102              0.00
# 103              0.00
# 104              0.00
#
# [104 rows x 9 columns]

# %%
Download.dtypes
# Out:
# Position             object
# Name + ID            object
# Name                 object
# ID                    int64
# Roster Position      object
# Salary                int64
# Game Info            object
# TeamAbbrev           object
# AvgPointsPerGame    float64
# dtype: object

# %%
Download["KingCost"]=Download["Salary"]*1.5

# %%
Download
# Out:
#     Position                       Name + ID                 Name        ID  \
# 1         RB  Christian McCaffrey (19289790)  Christian McCaffrey  19289790
# 2         QB          Sam Darnold (19289791)          Sam Darnold  19289791
# 3         WR             DJ Moore (19289792)             DJ Moore  19289792
# 4         WR        Brandin Cooks (19289793)        Brandin Cooks  19289793
# 5         QB         Tyrod Taylor (19289794)         Tyrod Taylor  19289794
# ..       ...                             ...                  ...       ...
# 100       WR          Chris Moore (19289785)          Chris Moore  19289785
# 101       TE        Brevin Jordan (19289786)        Brevin Jordan  19289786
# 102       RB        Spencer Brown (19289787)        Spencer Brown  19289787
# 103       WR           Jalen Camp (19289788)           Jalen Camp  19289788
# 104       WR         Jordan Veasy (19289789)         Jordan Veasy  19289789
#
#     Roster Position  Salary                      Game Info TeamAbbrev  \
# 1               CPT   20100  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 2               CPT   16800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 3               CPT   15900  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 4               CPT   15000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 5               CPT   14700  CAR@HOU 09/23/2021 08:20PM ET        HOU
# ..              ...     ...                            ...        ...
# 100            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 101            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 102            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 103            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 104            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
#
#      AvgPointsPerGame  KingCost
# 1               26.20   30150.0
# 2               21.48   25200.0
# 3               18.65   23850.0
# 4               22.00   22500.0
# 5               20.07   22050.0
# ..                ...       ...
# 100              0.00     300.0
# 101              0.00     300.0
# 102              0.00     300.0
# 103              0.00     300.0
# 104              0.00     300.0
#
# [104 rows x 10 columns]

# %%
Download=Download.loc[((Download['Roster Position'] != "CPT"))]

# %%
Download.index = np.arange(1, len(Download)+1)
Download
# Out:
#    Position                        Name + ID                  Name        ID  \
# 1        RB   Christian McCaffrey (19289738)   Christian McCaffrey  19289738
# 2        QB           Sam Darnold (19289739)           Sam Darnold  19289739
# 3        WR              DJ Moore (19289740)              DJ Moore  19289740
# 4        WR         Brandin Cooks (19289741)         Brandin Cooks  19289741
# 5        QB          Tyrod Taylor (19289742)          Tyrod Taylor  19289742
# 6        QB           Davis Mills (19289743)           Davis Mills  19289743
# 7        WR        Robby Anderson (19289744)        Robby Anderson  19289744
# 8        RB        Mark Ingram II (19289745)        Mark Ingram II  19289745
# 9       DST             Panthers  (19289746)             Panthers   19289746
# 10       QB           P.J. Walker (19289747)           P.J. Walker  19289747
# 11       QB        Deshaun Watson (19289748)        Deshaun Watson  19289748
# 12       QB          James Morgan (19289749)          James Morgan  19289749
# 13       QB          Jeff Driskel (19289750)          Jeff Driskel  19289750
# 14       RB       Phillip Lindsay (19289751)       Phillip Lindsay  19289751
# 15       RB         David Johnson (19289752)         David Johnson  19289752
# 16       TE            Dan Arnold (19289753)            Dan Arnold  19289753
# 17       WR       Brandon Zylstra (19289754)       Brandon Zylstra  19289754
# 18       WR  Terrace Marshall Jr. (19289755)  Terrace Marshall Jr.  19289755
# 19        K        Dominik Eberle (19289756)        Dominik Eberle  19289756
# 20        K         Zane Gonzalez (19289757)         Zane Gonzalez  19289757
# 21        K      Ka'imi Fairbairn (19289758)      Ka'imi Fairbairn  19289758
# 22        K             Joey Slye (19289759)             Joey Slye  19289759
# 23       RB         Chuba Hubbard (19289760)         Chuba Hubbard  19289760
# 24      DST               Texans  (19289761)               Texans   19289761
# 25       TE         Pharaoh Brown (19289762)         Pharaoh Brown  19289762
# 26       TE          Jordan Akins (19289763)          Jordan Akins  19289763
# 27       TE            Ian Thomas (19289764)            Ian Thomas  19289764
# 28       WR          Chris Conley (19289765)          Chris Conley  19289765
# 29       WR        Danny Amendola (19289766)        Danny Amendola  19289766
# 30       WR        Anthony Miller (19289767)        Anthony Miller  19289767
# 31       WR          Nico Collins (19289768)          Nico Collins  19289768
# 32       WR         Andre Roberts (19289769)         Andre Roberts  19289769
# 33       RB         Royce Freeman (19289770)         Royce Freeman  19289770
# 34       WR         Alex Erickson (19289771)         Alex Erickson  19289771
# 35       RB          Rodney Smith (19289772)          Rodney Smith  19289772
# 36       RB        Giovanni Ricci (19289773)        Giovanni Ricci  19289773
# 37       RB      Scottie Phillips (19289774)      Scottie Phillips  19289774
# 38       WR         C.J. Saunders (19289775)         C.J. Saunders  19289775
# 39       WR          Aaron Parker (19289776)          Aaron Parker  19289776
# 40       WR        Keith Kirkwood (19289777)        Keith Kirkwood  19289777
# 41       WR             Shi Smith (19289778)             Shi Smith  19289778
# 42       TE         Tommy Tremble (19289779)         Tommy Tremble  19289779
# 43       RB          Rex Burkhead (19289780)          Rex Burkhead  19289780
# 44       TE      Stephen Sullivan (19289781)      Stephen Sullivan  19289781
# 45       TE        Colin Thompson (19289782)        Colin Thompson  19289782
# 46       TE     Paul Quessenberry (19289783)     Paul Quessenberry  19289783
# 47       TE        Antony Auclair (19289784)        Antony Auclair  19289784
# 48       WR           Chris Moore (19289785)           Chris Moore  19289785
# 49       TE         Brevin Jordan (19289786)         Brevin Jordan  19289786
# 50       RB         Spencer Brown (19289787)         Spencer Brown  19289787
# 51       WR            Jalen Camp (19289788)            Jalen Camp  19289788
# 52       WR          Jordan Veasy (19289789)          Jordan Veasy  19289789
#
#    Roster Position  Salary                      Game Info TeamAbbrev  \
# 1             FLEX   13400  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 2             FLEX   11200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 3             FLEX   10600  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 4             FLEX   10000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 5             FLEX    9800  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 6             FLEX    8400  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 7             FLEX    7800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 8             FLEX    6600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 9             FLEX    6200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 10            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 11            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 12            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 13            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 14            FLEX    5800  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 15            FLEX    5400  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 16            FLEX    4800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 17            FLEX    4600  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 18            FLEX    4000  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 19            FLEX    3800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 20            FLEX    3800  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 21            FLEX    3600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 22            FLEX    3600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 23            FLEX    3200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 24            FLEX    3000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 25            FLEX    2600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 26            FLEX    2200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 27            FLEX    2000  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 28            FLEX    1600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 29            FLEX    1200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 30            FLEX    1000  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 31            FLEX     800  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 32            FLEX     600  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 33            FLEX     400  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 34            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 35            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 36            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 37            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 38            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 39            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 40            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 41            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 42            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 43            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 44            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 45            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 46            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 47            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 48            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 49            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 50            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        CAR
# 51            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
# 52            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET        HOU
#
#     AvgPointsPerGame  KingCost
# 1              26.20   20100.0
# 2              21.48   16800.0
# 3              18.65   15900.0
# 4              22.00   15000.0
# 5              20.07   14700.0
# 6               6.98   12600.0
# 7               9.75   11700.0
# 8               9.75    9900.0
# 9              10.50    9300.0
# 10              0.00    9000.0
# 11              0.00    9000.0
# 12              0.00    9000.0
# 13              0.00    9000.0
# 14              8.95    8700.0
# 15              9.25    8100.0
# 16              5.55    7200.0
# 17              6.70    6900.0
# 18              5.15    6000.0
# 19              0.00    5700.0
# 20              9.00    5700.0
# 21              0.00    5400.0
# 22              8.50    5400.0
# 23              1.70    4800.0
# 24              6.00    4500.0
# 25              5.35    3900.0
# 26              1.35    3300.0
# 27              2.20    3000.0
# 28              3.50    2400.0
# 29              8.15    1800.0
# 30              0.00    1500.0
# 31              2.95    1200.0
# 32              1.75     900.0
# 33              0.00     600.0
# 34              0.00     300.0
# 35              0.00     300.0
# 36              0.00     300.0
# 37              0.00     300.0
# 38              0.00     300.0
# 39              0.00     300.0
# 40              0.00     300.0
# 41              0.00     300.0
# 42              0.00     300.0
# 43              0.80     300.0
# 44              0.00     300.0
# 45              0.00     300.0
# 46              0.00     300.0
# 47              0.00     300.0
# 48              0.00     300.0
# 49              0.00     300.0
# 50              0.00     300.0
# 51              0.00     300.0
# 52              0.00     300.0

# %%
Code_list=['x1x2','x3x4','x5x6','x7x8','x9x10',
           'x11x12','x13x14','x15x16','x17x18',
           'x19x20','x21x22','x23x24','x25x26',
           'x27x28','x29x30','x31x32','x33x34',
           'x35x36','x37x38','x39x40','x41x42',
           'x43x44','x45x46','x47x48','x49x50',
           'x51x52','x53x54','x55x56','x57x58',
           'x59x60','x61x62','x63x64','x65x66',
           'x67x68','x69x70','x71x72','x73x74',
           'x75x76','x77x78','x79x80','x81x82',
           'x83x84','x85x86','x87x88','x89x90',
           'x91x92','x93x94','x95x96','x97x98',
           'x99x100','x101x102','x103x104']

# %%
Download.index = Code_list

# %%
#Download["King Salary"]=Download["Salary"]*1.5

# %%
Download
# Out:
#          Position                        Name + ID                  Name  \
# x1x2           RB   Christian McCaffrey (19289738)   Christian McCaffrey
# x3x4           QB           Sam Darnold (19289739)           Sam Darnold
# x5x6           WR              DJ Moore (19289740)              DJ Moore
# x7x8           WR         Brandin Cooks (19289741)         Brandin Cooks
# x9x10          QB          Tyrod Taylor (19289742)          Tyrod Taylor
# x11x12         QB           Davis Mills (19289743)           Davis Mills
# x13x14         WR        Robby Anderson (19289744)        Robby Anderson
# x15x16         RB        Mark Ingram II (19289745)        Mark Ingram II
# x17x18        DST             Panthers  (19289746)             Panthers
# x19x20         QB           P.J. Walker (19289747)           P.J. Walker
# x21x22         QB        Deshaun Watson (19289748)        Deshaun Watson
# x23x24         QB          James Morgan (19289749)          James Morgan
# x25x26         QB          Jeff Driskel (19289750)          Jeff Driskel
# x27x28         RB       Phillip Lindsay (19289751)       Phillip Lindsay
# x29x30         RB         David Johnson (19289752)         David Johnson
# x31x32         TE            Dan Arnold (19289753)            Dan Arnold
# x33x34         WR       Brandon Zylstra (19289754)       Brandon Zylstra
# x35x36         WR  Terrace Marshall Jr. (19289755)  Terrace Marshall Jr.
# x37x38          K        Dominik Eberle (19289756)        Dominik Eberle
# x39x40          K         Zane Gonzalez (19289757)         Zane Gonzalez
# x41x42          K      Ka'imi Fairbairn (19289758)      Ka'imi Fairbairn
# x43x44          K             Joey Slye (19289759)             Joey Slye
# x45x46         RB         Chuba Hubbard (19289760)         Chuba Hubbard
# x47x48        DST               Texans  (19289761)               Texans
# x49x50         TE         Pharaoh Brown (19289762)         Pharaoh Brown
# x51x52         TE          Jordan Akins (19289763)          Jordan Akins
# x53x54         TE            Ian Thomas (19289764)            Ian Thomas
# x55x56         WR          Chris Conley (19289765)          Chris Conley
# x57x58         WR        Danny Amendola (19289766)        Danny Amendola
# x59x60         WR        Anthony Miller (19289767)        Anthony Miller
# x61x62         WR          Nico Collins (19289768)          Nico Collins
# x63x64         WR         Andre Roberts (19289769)         Andre Roberts
# x65x66         RB         Royce Freeman (19289770)         Royce Freeman
# x67x68         WR         Alex Erickson (19289771)         Alex Erickson
# x69x70         RB          Rodney Smith (19289772)          Rodney Smith
# x71x72         RB        Giovanni Ricci (19289773)        Giovanni Ricci
# x73x74         RB      Scottie Phillips (19289774)      Scottie Phillips
# x75x76         WR         C.J. Saunders (19289775)         C.J. Saunders
# x77x78         WR          Aaron Parker (19289776)          Aaron Parker
# x79x80         WR        Keith Kirkwood (19289777)        Keith Kirkwood
# x81x82         WR             Shi Smith (19289778)             Shi Smith
# x83x84         TE         Tommy Tremble (19289779)         Tommy Tremble
# x85x86         RB          Rex Burkhead (19289780)          Rex Burkhead
# x87x88         TE      Stephen Sullivan (19289781)      Stephen Sullivan
# x89x90         TE        Colin Thompson (19289782)        Colin Thompson
# x91x92         TE     Paul Quessenberry (19289783)     Paul Quessenberry
# x93x94         TE        Antony Auclair (19289784)        Antony Auclair
# x95x96         WR           Chris Moore (19289785)           Chris Moore
# x97x98         TE         Brevin Jordan (19289786)         Brevin Jordan
# x99x100        RB         Spencer Brown (19289787)         Spencer Brown
# x101x102       WR            Jalen Camp (19289788)            Jalen Camp
# x103x104       WR          Jordan Veasy (19289789)          Jordan Veasy
#
#                 ID Roster Position  Salary                      Game Info  \
# x1x2      19289738            FLEX   13400  CAR@HOU 09/23/2021 08:20PM ET
# x3x4      19289739            FLEX   11200  CAR@HOU 09/23/2021 08:20PM ET
# x5x6      19289740            FLEX   10600  CAR@HOU 09/23/2021 08:20PM ET
# x7x8      19289741            FLEX   10000  CAR@HOU 09/23/2021 08:20PM ET
# x9x10     19289742            FLEX    9800  CAR@HOU 09/23/2021 08:20PM ET
# x11x12    19289743            FLEX    8400  CAR@HOU 09/23/2021 08:20PM ET
# x13x14    19289744            FLEX    7800  CAR@HOU 09/23/2021 08:20PM ET
# x15x16    19289745            FLEX    6600  CAR@HOU 09/23/2021 08:20PM ET
# x17x18    19289746            FLEX    6200  CAR@HOU 09/23/2021 08:20PM ET
# x19x20    19289747            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET
# x21x22    19289748            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET
# x23x24    19289749            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET
# x25x26    19289750            FLEX    6000  CAR@HOU 09/23/2021 08:20PM ET
# x27x28    19289751            FLEX    5800  CAR@HOU 09/23/2021 08:20PM ET
# x29x30    19289752            FLEX    5400  CAR@HOU 09/23/2021 08:20PM ET
# x31x32    19289753            FLEX    4800  CAR@HOU 09/23/2021 08:20PM ET
# x33x34    19289754            FLEX    4600  CAR@HOU 09/23/2021 08:20PM ET
# x35x36    19289755            FLEX    4000  CAR@HOU 09/23/2021 08:20PM ET
# x37x38    19289756            FLEX    3800  CAR@HOU 09/23/2021 08:20PM ET
# x39x40    19289757            FLEX    3800  CAR@HOU 09/23/2021 08:20PM ET
# x41x42    19289758            FLEX    3600  CAR@HOU 09/23/2021 08:20PM ET
# x43x44    19289759            FLEX    3600  CAR@HOU 09/23/2021 08:20PM ET
# x45x46    19289760            FLEX    3200  CAR@HOU 09/23/2021 08:20PM ET
# x47x48    19289761            FLEX    3000  CAR@HOU 09/23/2021 08:20PM ET
# x49x50    19289762            FLEX    2600  CAR@HOU 09/23/2021 08:20PM ET
# x51x52    19289763            FLEX    2200  CAR@HOU 09/23/2021 08:20PM ET
# x53x54    19289764            FLEX    2000  CAR@HOU 09/23/2021 08:20PM ET
# x55x56    19289765            FLEX    1600  CAR@HOU 09/23/2021 08:20PM ET
# x57x58    19289766            FLEX    1200  CAR@HOU 09/23/2021 08:20PM ET
# x59x60    19289767            FLEX    1000  CAR@HOU 09/23/2021 08:20PM ET
# x61x62    19289768            FLEX     800  CAR@HOU 09/23/2021 08:20PM ET
# x63x64    19289769            FLEX     600  CAR@HOU 09/23/2021 08:20PM ET
# x65x66    19289770            FLEX     400  CAR@HOU 09/23/2021 08:20PM ET
# x67x68    19289771            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x69x70    19289772            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x71x72    19289773            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x73x74    19289774            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x75x76    19289775            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x77x78    19289776            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x79x80    19289777            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x81x82    19289778            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x83x84    19289779            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x85x86    19289780            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x87x88    19289781            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x89x90    19289782            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x91x92    19289783            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x93x94    19289784            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x95x96    19289785            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x97x98    19289786            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x99x100   19289787            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x101x102  19289788            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
# x103x104  19289789            FLEX     200  CAR@HOU 09/23/2021 08:20PM ET
#
#          TeamAbbrev  AvgPointsPerGame  KingCost
# x1x2            CAR             26.20   20100.0
# x3x4            CAR             21.48   16800.0
# x5x6            CAR             18.65   15900.0
# x7x8            HOU             22.00   15000.0
# x9x10           HOU             20.07   14700.0
# x11x12          HOU              6.98   12600.0
# x13x14          CAR              9.75   11700.0
# x15x16          HOU              9.75    9900.0
# x17x18          CAR             10.50    9300.0
# x19x20          CAR              0.00    9000.0
# x21x22          HOU              0.00    9000.0
# x23x24          CAR              0.00    9000.0
# x25x26          HOU              0.00    9000.0
# x27x28          HOU              8.95    8700.0
# x29x30          HOU              9.25    8100.0
# x31x32          CAR              5.55    7200.0
# x33x34          CAR              6.70    6900.0
# x35x36          CAR              5.15    6000.0
# x37x38          CAR              0.00    5700.0
# x39x40          CAR              9.00    5700.0
# x41x42          HOU              0.00    5400.0
# x43x44          HOU              8.50    5400.0
# x45x46          CAR              1.70    4800.0
# x47x48          HOU              6.00    4500.0
# x49x50          HOU              5.35    3900.0
# x51x52          HOU              1.35    3300.0
# x53x54          CAR              2.20    3000.0
# x55x56          HOU              3.50    2400.0
# x57x58          HOU              8.15    1800.0
# x59x60          HOU              0.00    1500.0
# x61x62          HOU              2.95    1200.0
# x63x64          HOU              1.75     900.0
# x65x66          CAR              0.00     600.0
# x67x68          CAR              0.00     300.0
# x69x70          CAR              0.00     300.0
# x71x72          CAR              0.00     300.0
# x73x74          HOU              0.00     300.0
# x75x76          CAR              0.00     300.0
# x77x78          CAR              0.00     300.0
# x79x80          CAR              0.00     300.0
# x81x82          CAR              0.00     300.0
# x83x84          CAR              0.00     300.0
# x85x86          HOU              0.80     300.0
# x87x88          CAR              0.00     300.0
# x89x90          CAR              0.00     300.0
# x91x92          HOU              0.00     300.0
# x93x94          HOU              0.00     300.0
# x95x96          HOU              0.00     300.0
# x97x98          HOU              0.00     300.0
# x99x100         CAR              0.00     300.0
# x101x102        HOU              0.00     300.0
# x103x104        HOU              0.00     300.0

# %%
dictionary=pd.Series(Download.KingCost.values,index=Download.Name).to_dict()

# %%
dictionary
# Out:
# {'Christian McCaffrey': 20100.0,
#  'Sam Darnold': 16800.0,
#  'DJ Moore': 15900.0,
#  'Brandin Cooks': 15000.0,
#  'Tyrod Taylor': 14700.0,
#  'Davis Mills': 12600.0,
#  'Robby Anderson': 11700.0,
#  'Mark Ingram II': 9900.0,
#  'Panthers ': 9300.0,
#  'P.J. Walker': 9000.0,
#  'Deshaun Watson': 9000.0,
#  'James Morgan': 9000.0,
#  'Jeff Driskel': 9000.0,
#  'Phillip Lindsay': 8700.0,
#  'David Johnson': 8100.0,
#  'Dan Arnold': 7200.0,
#  'Brandon Zylstra': 6900.0,
#  'Terrace Marshall Jr.': 6000.0,
#  'Dominik Eberle': 5700.0,
#  'Zane Gonzalez': 5700.0,
#  "Ka'imi Fairbairn": 5400.0,
#  'Joey Slye': 5400.0,
#  'Chuba Hubbard': 4800.0,
#  'Texans ': 4500.0,
#  'Pharaoh Brown': 3900.0,
#  'Jordan Akins': 3300.0,
#  'Ian Thomas': 3000.0,
#  'Chris Conley': 2400.0,
#  'Danny Amendola': 1800.0,
#  'Anthony Miller': 1500.0,
#  'Nico Collins': 1200.0,
#  'Andre Roberts': 900.0,
#  'Royce Freeman': 600.0,
#  'Alex Erickson': 300.0,
#  'Rodney Smith': 300.0,
#  'Giovanni Ricci': 300.0,
#  'Scottie Phillips': 300.0,
#  'C.J. Saunders': 300.0,
#  'Aaron Parker': 300.0,
#  'Keith Kirkwood': 300.0,
#  'Shi Smith': 300.0,
#  'Tommy Tremble': 300.0,
#  'Rex Burkhead': 300.0,
#  'Stephen Sullivan': 300.0,
#  'Colin Thompson': 300.0,
#  'Paul Quessenberry': 300.0,
#  'Antony Auclair': 300.0,
#  'Chris Moore': 300.0,
#  'Brevin Jordan': 300.0,
#  'Spencer Brown': 300.0,
#  'Jalen Camp': 300.0,
#  'Jordan Veasy': 300.0}

# %%
test_dict = dictionary
res = ' '
 
for item in test_dict:
    res += '('+item+'*'+str(test_dict[item])+')'+'+'+'('+item+'2'+'*'+str(test_dict[item])+'*'+'1.5'+')'+'+' 
    test=res
# printing result
print(test)


#This will be helpful eventually

#d = eval('4 + 5')
#print d

#s = ""
#s = s + "some string"
#print s
# Out:
#  (Christian McCaffrey*20100.0)+(Christian McCaffrey2*20100.0*1.5)+(Sam Darnold*16800.0)+(Sam Darnold2*16800.0*1.5)+(DJ Moore*15900.0)+(DJ Moore2*15900.0*1.5)+(Brandin Cooks*15000.0)+(Brandin Cooks2*15000.0*1.5)+(Tyrod Taylor*14700.0)+(Tyrod Taylor2*14700.0*1.5)+(Davis Mills*12600.0)+(Davis Mills2*12600.0*1.5)+(Robby Anderson*11700.0)+(Robby Anderson2*11700.0*1.5)+(Mark Ingram II*9900.0)+(Mark Ingram II2*9900.0*1.5)+(Panthers *9300.0)+(Panthers 2*9300.0*1.5)+(P.J. Walker*9000.0)+(P.J. Walker2*9000.0*1.5)+(Deshaun Watson*9000.0)+(Deshaun Watson2*9000.0*1.5)+(James Morgan*9000.0)+(James Morgan2*9000.0*1.5)+(Jeff Driskel*9000.0)+(Jeff Driskel2*9000.0*1.5)+(Phillip Lindsay*8700.0)+(Phillip Lindsay2*8700.0*1.5)+(David Johnson*8100.0)+(David Johnson2*8100.0*1.5)+(Dan Arnold*7200.0)+(Dan Arnold2*7200.0*1.5)+(Brandon Zylstra*6900.0)+(Brandon Zylstra2*6900.0*1.5)+(Terrace Marshall Jr.*6000.0)+(Terrace Marshall Jr.2*6000.0*1.5)+(Dominik Eberle*5700.0)+(Dominik Eberle2*5700.0*1.5)+(Zane Gonzalez*5700.0)+(Zane Gonzalez2*5700.0*1.5)+(Ka'imi Fairbairn*5400.0)+(Ka'imi Fairbairn2*5400.0*1.5)+(Joey Slye*5400.0)+(Joey Slye2*5400.0*1.5)+(Chuba Hubbard*4800.0)+(Chuba Hubbard2*4800.0*1.5)+(Texans *4500.0)+(Texans 2*4500.0*1.5)+(Pharaoh Brown*3900.0)+(Pharaoh Brown2*3900.0*1.5)+(Jordan Akins*3300.0)+(Jordan Akins2*3300.0*1.5)+(Ian Thomas*3000.0)+(Ian Thomas2*3000.0*1.5)+(Chris Conley*2400.0)+(Chris Conley2*2400.0*1.5)+(Danny Amendola*1800.0)+(Danny Amendola2*1800.0*1.5)+(Anthony Miller*1500.0)+(Anthony Miller2*1500.0*1.5)+(Nico Collins*1200.0)+(Nico Collins2*1200.0*1.5)+(Andre Roberts*900.0)+(Andre Roberts2*900.0*1.5)+(Royce Freeman*600.0)+(Royce Freeman2*600.0*1.5)+(Alex Erickson*300.0)+(Alex Erickson2*300.0*1.5)+(Rodney Smith*300.0)+(Rodney Smith2*300.0*1.5)+(Giovanni Ricci*300.0)+(Giovanni Ricci2*300.0*1.5)+(Scottie Phillips*300.0)+(Scottie Phillips2*300.0*1.5)+(C.J. Saunders*300.0)+(C.J. Saunders2*300.0*1.5)+(Aaron Parker*300.0)+(Aaron Parker2*300.0*1.5)+(Keith Kirkwood*300.0)+(Keith Kirkwood2*300.0*1.5)+(Shi Smith*300.0)+(Shi Smith2*300.0*1.5)+(Tommy Tremble*300.0)+(Tommy Tremble2*300.0*1.5)+(Rex Burkhead*300.0)+(Rex Burkhead2*300.0*1.5)+(Stephen Sullivan*300.0)+(Stephen Sullivan2*300.0*1.5)+(Colin Thompson*300.0)+(Colin Thompson2*300.0*1.5)+(Paul Quessenberry*300.0)+(Paul Quessenberry2*300.0*1.5)+(Antony Auclair*300.0)+(Antony Auclair2*300.0*1.5)+(Chris Moore*300.0)+(Chris Moore2*300.0*1.5)+(Brevin Jordan*300.0)+(Brevin Jordan2*300.0*1.5)+(Spencer Brown*300.0)+(Spencer Brown2*300.0*1.5)+(Jalen Camp*300.0)+(Jalen Camp2*300.0*1.5)+(Jordan Veasy*300.0)+(Jordan Veasy2*300.0*1.5)+

# %%
test = test[:-1]


test += '<=50000'

# %%
test
# Out:
# " (Christian McCaffrey*20100.0)+(Christian McCaffrey2*20100.0*1.5)+(Sam Darnold*16800.0)+(Sam Darnold2*16800.0*1.5)+(DJ Moore*15900.0)+(DJ Moore2*15900.0*1.5)+(Brandin Cooks*15000.0)+(Brandin Cooks2*15000.0*1.5)+(Tyrod Taylor*14700.0)+(Tyrod Taylor2*14700.0*1.5)+(Davis Mills*12600.0)+(Davis Mills2*12600.0*1.5)+(Robby Anderson*11700.0)+(Robby Anderson2*11700.0*1.5)+(Mark Ingram II*9900.0)+(Mark Ingram II2*9900.0*1.5)+(Panthers *9300.0)+(Panthers 2*9300.0*1.5)+(P.J. Walker*9000.0)+(P.J. Walker2*9000.0*1.5)+(Deshaun Watson*9000.0)+(Deshaun Watson2*9000.0*1.5)+(James Morgan*9000.0)+(James Morgan2*9000.0*1.5)+(Jeff Driskel*9000.0)+(Jeff Driskel2*9000.0*1.5)+(Phillip Lindsay*8700.0)+(Phillip Lindsay2*8700.0*1.5)+(David Johnson*8100.0)+(David Johnson2*8100.0*1.5)+(Dan Arnold*7200.0)+(Dan Arnold2*7200.0*1.5)+(Brandon Zylstra*6900.0)+(Brandon Zylstra2*6900.0*1.5)+(Terrace Marshall Jr.*6000.0)+(Terrace Marshall Jr.2*6000.0*1.5)+(Dominik Eberle*5700.0)+(Dominik Eberle2*5700.0*1.5)+(Zane Gonzalez*5700.0)+(Zane Gonzalez2*5700.0*1.5)+(Ka'imi Fairbairn*5400.0)+(Ka'imi Fairbairn2*5400.0*1.5)+(Joey Slye*5400.0)+(Joey Slye2*5400.0*1.5)+(Chuba Hubbard*4800.0)+(Chuba Hubbard2*4800.0*1.5)+(Texans *4500.0)+(Texans 2*4500.0*1.5)+(Pharaoh Brown*3900.0)+(Pharaoh Brown2*3900.0*1.5)+(Jordan Akins*3300.0)+(Jordan Akins2*3300.0*1.5)+(Ian Thomas*3000.0)+(Ian Thomas2*3000.0*1.5)+(Chris Conley*2400.0)+(Chris Conley2*2400.0*1.5)+(Danny Amendola*1800.0)+(Danny Amendola2*1800.0*1.5)+(Anthony Miller*1500.0)+(Anthony Miller2*1500.0*1.5)+(Nico Collins*1200.0)+(Nico Collins2*1200.0*1.5)+(Andre Roberts*900.0)+(Andre Roberts2*900.0*1.5)+(Royce Freeman*600.0)+(Royce Freeman2*600.0*1.5)+(Alex Erickson*300.0)+(Alex Erickson2*300.0*1.5)+(Rodney Smith*300.0)+(Rodney Smith2*300.0*1.5)+(Giovanni Ricci*300.0)+(Giovanni Ricci2*300.0*1.5)+(Scottie Phillips*300.0)+(Scottie Phillips2*300.0*1.5)+(C.J. Saunders*300.0)+(C.J. Saunders2*300.0*1.5)+(Aaron Parker*300.0)+(Aaron Parker2*300.0*1.5)+(Keith Kirkwood*300.0)+(Keith Kirkwood2*300.0*1.5)+(Shi Smith*300.0)+(Shi Smith2*300.0*1.5)+(Tommy Tremble*300.0)+(Tommy Tremble2*300.0*1.5)+(Rex Burkhead*300.0)+(Rex Burkhead2*300.0*1.5)+(Stephen Sullivan*300.0)+(Stephen Sullivan2*300.0*1.5)+(Colin Thompson*300.0)+(Colin Thompson2*300.0*1.5)+(Paul Quessenberry*300.0)+(Paul Quessenberry2*300.0*1.5)+(Antony Auclair*300.0)+(Antony Auclair2*300.0*1.5)+(Chris Moore*300.0)+(Chris Moore2*300.0*1.5)+(Brevin Jordan*300.0)+(Brevin Jordan2*300.0*1.5)+(Spencer Brown*300.0)+(Spencer Brown2*300.0*1.5)+(Jalen Camp*300.0)+(Jalen Camp2*300.0*1.5)+(Jordan Veasy*300.0)+(Jordan Veasy2*300.0*1.5)<=50000"

# %%
Download.iloc[9]['AvgPointsPerGame']
# Out:
# 0.0

# %%
Download.iloc[9]['Salary']
# Out:
# 6000

# %%
#Eventually this should be cleaned up so that a loop is used to generate these values.  
#This will reduce the potential of type errors

m = GEKKO() # create GEKKO model
# create binary variables
x1 = m.Var(integer=True,lb=0,ub=1) 
x2 = m.Var(integer=True,lb=0,ub=1)
x3 = m.Var(integer=True,lb=0,ub=1)
x4 = m.Var(integer=True,lb=0,ub=1)
x5 = m.Var(integer=True,lb=0,ub=1)

# %%
m.Equation(x2+x4+x6+x8+x10+x12+x14+x16+x18+x20+x22+x24+x26+x28+
           x30+x32+x34+x36+x38+x40+x42+x44+x46+x48+x50+x52+x54+x56+
           x58+x60+x62+x64+x66+x68+x70+x72+x74+x76+x78+x80+x82+x84+
           x86+x88+x90+x92+x94+x96+x98+x100+x102+x104==1)

m.Equation(x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x11+x12+x13+x14+
           x15+x16+x17+x18+x19+x20+x21+x22+x23+x24+x25+x26+x27+x28+
           x29+x30+x31+x32+x33+x34+x35+x36+x37+x38+x39+x40+x41+x42+
           x43+x44+x45+x46+x47+x48+x49+x50+x51+x52+x53+x54+x55+x56+
           x57+x58+x59+x60+x61+x62+x63+x64+x65+x66+x67+x68+x69+x70+
           x71+x72+x73+x74+x75+x76+x77+x78+x79+x80+x81+x82+x83+x84+
           x85+x86+x87+x88+x89+x90+x91+x92+x93+x94+x95+x96+x97+x98+
           x99+x100+x101+x102+x103+x104== 6)


m.Equation(x1+x2<=1)
m.Equation(x3+x4<=1)
m.Equation(x5+x6<=1)
m.Equation(x7+x8<=1)
m.Equation(x9+x10<=1)
m.Equation(x11+x12<=1)
m.Equation(x13+x14<=1)
m.Equation(x15+x16<=1)
m.Equation(x17+x18<=1)
m.Equation(x19+x20<=1)
m.Equation(x21+x22<=1)
m.Equation(x23+x24<=1)
m.Equation(x25+x26<=1)
m.Equation(x27+x28<=1)
m.Equation(x29+x30<=1)
m.Equation(x31+x32<=1)
m.Equation(x33+x34<=1)
m.Equation(x35+x36<=1)
m.Equation(x37+x38<=1)
m.Equation(x39+x40<=1)
m.Equation(x41+x42<=1)
m.Equation(x43+x44<=1)
m.Equation(x45+x46<=1)
m.Equation(x47+x48<=1)
m.Equation(x49+x50<=1)
m.Equation(x51+x52<=1)
m.Equation(x53+x54<=1)
m.Equation(x55+x56<=1)
m.Equation(x57+x58<=1)
m.Equation(x59+x60<=1)
m.Equation(x61+x62<=1)
m.Equation(x63+x64<=1)
m.Equation(x65+x66<=1)
m.Equation(x67+x68<=1)
m.Equation(x69+x70<=1)
m.Equation(x71+x72<=1)
m.Equation(x73+x74<=1)
m.Equation(x75+x76<=1)
m.Equation(x77+x78<=1)
m.Equation(x79+x80<=1)
m.Equation(x81+x82<=1)
m.Equation(x83+x84<=1)
m.Equation(x85+x86<=1)
m.Equation(x87+x88<=1)
m.Equation(x89+x90<=1)
m.Equation(x91+x92<=1)
m.Equation(x93+x94<=1)
m.Equation(x95+x96<=1)
m.Equation(x97+x98<=1)
m.Equation(x99+x100<=1)
m.Equation(x101+x102<=1)
m.Equation(x103+x104<=1)











m.Equation((x1*Download.iloc[0]['Salary'])+(x2*Download.iloc[0]['Salary']*1.5)+
            (x3*Download.iloc[1]['Salary'])+(x4*Download.iloc[1]['Salary']*1.5)+
            (x5*Download.iloc[2]['Salary'])+(x6*Download.iloc[2]['Salary']*1.5)+
            (x7*Download.iloc[3]['Salary'])+(x8*Download.iloc[3]['Salary']*1.5)+
            (x9*Download.iloc[4]['Salary'])+(x10*Download.iloc[4]['Salary']*1.5)+
            (x11*Download.iloc[5]['Salary'])+(x12*Download.iloc[5]['Salary']*1.5)+
            (x13*Download.iloc[6]['Salary'])+(x14*Download.iloc[6]['Salary']*1.5)+
            (x15*Download.iloc[7]['Salary'])+(x16*Download.iloc[7]['Salary']*1.5)+
            (x17*Download.iloc[8]['Salary'])+(x18*Download.iloc[8]['Salary']*1.5)+
            (x19*Download.iloc[9]['Salary'])+(x20*Download.iloc[9]['Salary']*1.5)+
            (x21*Download.iloc[10]['Salary'])+(x22*Download.iloc[10]['Salary']*1.5)+
            (x23*Download.iloc[11]['Salary'])+(x24*Download.iloc[11]['Salary']*1.5)+
            (x25*Download.iloc[12]['Salary'])+(x26*Download.iloc[12]['Salary']*1.5)+
            (x27*Download.iloc[13]['Salary'])+(x28*Download.iloc[13]['Salary']*1.5)<=50000)




m.Obj(-((x1*Download.iloc[0]['AvgPointsPerGame'])+(x2*Download.iloc[0]['AvgPointsPerGame']*1.5)+
        (x3*Download.iloc[1]['AvgPointsPerGame'])+(x4*Download.iloc[1]['AvgPointsPerGame']*1.5)+
        (x5*Download.iloc[2]['AvgPointsPerGame'])+(x6*Download.iloc[2]['AvgPointsPerGame']*1.5)+
        (x7*Download.iloc[3]['AvgPointsPerGame'])+(x8*Download.iloc[3]['AvgPointsPerGame']*1.5)+
        (x9*Download.iloc[4]['AvgPointsPerGame'])+(x10*Download.iloc[4]['AvgPointsPerGame']*1.5)+
        (x11*Download.iloc[5]['AvgPointsPerGame'])+(x12*Download.iloc[5]['AvgPointsPerGame']*1.5)+
        (x13*Download.iloc[6]['AvgPointsPerGame'])+(x14*Download.iloc[6]['AvgPointsPerGame']*1.5)+
        (x15*Download.iloc[7]['AvgPointsPerGame'])+(x16*Download.iloc[7]['AvgPointsPerGame']*1.5)+
        (x17*Download.iloc[8]['AvgPointsPerGame'])+(x18*Download.iloc[8]['AvgPointsPerGame']*1.5)+
        (x19*Download.iloc[9]['AvgPointsPerGame'])+(x20*Download.iloc[9]['AvgPointsPerGame']*1.5)+
        (x21*Download.iloc[10]['AvgPointsPerGame'])+(x22*Download.iloc[10]['AvgPointsPerGame']*1.5)+
        (x23*Download.iloc[11]['AvgPointsPerGame'])+(x24*Download.iloc[11]['AvgPointsPerGame']*1.5)+
        (x25*Download.iloc[12]['AvgPointsPerGame'])+(x26*Download.iloc[12]['AvgPointsPerGame']*1.5)+
        (x27*Download.iloc[13]['AvgPointsPerGame'])+(x28*Download.iloc[13]['AvgPointsPerGame']*1.5)))





m.options.SOLVER = 1 # APOPT solver
m.solve()
print('x1: ' + str(x1.value[0]))
print('x2: ' + str(x2.value[0]))
print('x3: ' + str(x3.value[0]))
print('x4: ' + str(x4.value[0]))
print('x5: ' + str(x5.value[0]))
print('x6: ' + str(x6.value[0]))
print('x7: ' + str(x7.value[0]))
print('x8: ' + str(x8.value[0]))
print('x9: ' + str(x9.value[0]))
print('x10: ' + str(x10.value[0]))
print('x11: ' + str(x11.value[0]))
print('x12: ' + str(x12.value[0]))
print('x13: ' + str(x13.value[0]))
print('x14: ' + str(x14.value[0]))
print('x15: ' + str(x15.value[0]))
print('x16: ' + str(x16.value[0]))
print('x17: ' + str(x17.value[0]))
print('x18: ' + str(x18.value[0]))
print('x19: ' + str(x19.value[0]))
print('x20: ' + str(x20.value[0]))
print('x21: ' + str(x21.value[0]))
print('x22: ' + str(x22.value[0]))
print('x23: ' + str(x23.value[0]))
print('x24: ' + str(x24.value[0]))
print('x25: ' + str(x25.value[0]))
print('x26: ' + str(x26.value[0]))
print('x27: ' + str(x27.value[0]))
print('x28: ' + str(x28.value[0]))
print('x29: ' + str(x29.value[0]))
print('x30: ' + str(x30.value[0]))
print('x31: ' + str(x31.value[0]))
print('x32: ' + str(x32.value[0]))
print('x33: ' + str(x33.value[0]))
print('x34: ' + str(x34.value[0]))
print('x35: ' + str(x35.value[0]))
print('x36: ' + str(x36.value[0]))
print('x37: ' + str(x37.value[0]))
print('x38: ' + str(x38.value[0]))
print('x39: ' + str(x39.value[0]))
print('x40: ' + str(x40.value[0]))
print('x41: ' + str(x41.value[0]))
print('x42: ' + str(x42.value[0]))
print('x43: ' + str(x43.value[0]))
print('x44: ' + str(x44.value[0]))
print('x45: ' + str(x45.value[0]))
print('x46: ' + str(x46.value[0]))
print('x47: ' + str(x47.value[0]))
print('x48: ' + str(x48.value[0]))
print('x49: ' + str(x49.value[0]))
print('x50: ' + str(x50.value[0]))
print('x51: ' + str(x51.value[0]))
print('x52: ' + str(x52.value[0]))
print('x53: ' + str(x53.value[0]))
print('x54: ' + str(x54.value[0]))
print('x55: ' + str(x55.value[0]))
print('x56: ' + str(x56.value[0]))
print('x57: ' + str(x57.value[0]))
print('x58: ' + str(x58.value[0]))
print('x59: ' + str(x59.value[0]))
print('x60: ' + str(x60.value[0]))
print('x61: ' + str(x61.value[0]))
print('x62: ' + str(x62.value[0]))
print('x63: ' + str(x63.value[0]))
print('x64: ' + str(x64.value[0]))
print('x65: ' + str(x65.value[0]))
print('x66: ' + str(x66.value[0]))
print('x67: ' + str(x67.value[0]))
print('x68: ' + str(x68.value[0]))
print('x69: ' + str(x69.value[0]))
print('x70: ' + str(x70.value[0]))
print('x71: ' + str(x71.value[0]))
print('x72: ' + str(x72.value[0]))
print('x73: ' + str(x73.value[0]))
print('x74: ' + str(x74.value[0]))
print('x75: ' + str(x75.value[0]))
print('x76: ' + str(x76.value[0]))
print('x77: ' + str(x77.value[0]))
print('x78: ' + str(x78.value[0]))
print('x79: ' + str(x79.value[0]))
print('x80: ' + str(x80.value[0]))
print('x81: ' + str(x81.value[0]))
print('x82: ' + str(x82.value[0]))
print('x83: ' + str(x83.value[0]))
print('x84: ' + str(x84.value[0]))
print('x85: ' + str(x85.value[0]))
print('x86: ' + str(x86.value[0]))
print('x87: ' + str(x87.value[0]))
print('x88: ' + str(x88.value[0]))
print('x89: ' + str(x89.value[0]))
print('x90: ' + str(x90.value[0]))
print('x91: ' + str(x91.value[0]))
print('x92: ' + str(x92.value[0]))
print('x93: ' + str(x93.value[0]))
print('x94: ' + str(x94.value[0]))
print('x95: ' + str(x95.value[0]))
print('x96: ' + str(x96.value[0]))
print('x97: ' + str(x97.value[0]))
print('x98: ' + str(x98.value[0]))
print('x99: ' + str(x99.value[0]))
print('x100: ' + str(x100.value[0]))
print('x101: ' + str(x101.value[0]))
print('x102: ' + str(x102.value[0]))
print('x103: ' + str(x103.value[0]))
print('x104: ' + str(x104.value[0]))
# Out:
# apm 108.183.51.97_gk_model1 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.1
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  Warning: there is insufficient data in CSV file 108.183.51.97_gk_model1.csv
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :          157
#    Intermediates:            0
#    Connections  :            0
#    Equations    :           56
#    Residuals    :           56
#
#  Number of state variables:            157
#  Number of total equations: -           55
#  Number of slack variables: -           53
#  ---------------------------------------
#  Degrees of freedom       :             49
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.01 NLPi:    4 Dpth:    0 Lvs:    3 Obj: -1.02E+02 Gap:       NaN
# Iter:     2 I: -1 Tm:      0.00 NLPi:    1 Dpth:    1 Lvs:    2 Obj: -1.02E+02 Gap:       NaN
# Iter:     3 I:  0 Tm:      0.00 NLPi:    3 Dpth:    1 Lvs:    4 Obj: -1.00E+02 Gap:       NaN
# Iter:     4 I:  0 Tm:      0.00 NLPi:    3 Dpth:    1 Lvs:    5 Obj: -1.02E+02 Gap:       NaN
# Iter:     5 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:    7 Obj: -1.01E+02 Gap:       NaN
# Iter:     6 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:    9 Obj: -1.02E+02 Gap:       NaN
# Iter:     7 I: -1 Tm:      0.00 NLPi:    1 Dpth:    3 Lvs:    8 Obj: -1.02E+02 Gap:       NaN
# Iter:     8 I:  0 Tm:      0.01 NLPi:    3 Dpth:    3 Lvs:   10 Obj: -1.01E+02 Gap:       NaN
# Iter:     9 I:  0 Tm:      0.00 NLPi:    3 Dpth:    3 Lvs:   11 Obj: -1.02E+02 Gap:       NaN
# Iter:    10 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   13 Obj: -9.97E+01 Gap:       NaN
# Iter:    11 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   14 Obj: -1.02E+02 Gap:       NaN
# Iter:    12 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   16 Obj: -9.90E+01 Gap:       NaN
# Iter:    13 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   17 Obj: -1.02E+02 Gap:       NaN
# Iter:    14 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   19 Obj: -9.67E+01 Gap:       NaN
# Iter:    15 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   20 Obj: -1.01E+02 Gap:       NaN
# Iter:    16 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   22 Obj: -9.28E+01 Gap:       NaN
# Iter:    17 I:  0 Tm:      0.00 NLPi:    2 Dpth:    7 Lvs:   23 Obj: -1.01E+02 Gap:       NaN
# Iter:    18 I: -1 Tm:      0.00 NLPi:    1 Dpth:    4 Lvs:   22 Obj: -1.01E+02 Gap:       NaN
# Iter:    19 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   24 Obj: -1.01E+02 Gap:       NaN
# Iter:    20 I:  0 Tm:      0.01 NLPi:    4 Dpth:    4 Lvs:   26 Obj: -1.01E+02 Gap:       NaN
# Iter:    21 I: -1 Tm:      0.00 NLPi:    1 Dpth:    5 Lvs:   25 Obj: -1.01E+02 Gap:       NaN
# Iter:    22 I:  0 Tm:      0.01 NLPi:    4 Dpth:    5 Lvs:   27 Obj: -9.90E+01 Gap:       NaN
# Iter:    23 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   28 Obj: -1.01E+02 Gap:       NaN
# Iter:    24 I:  0 Tm:      0.01 NLPi:    4 Dpth:    6 Lvs:   30 Obj: -9.82E+01 Gap:       NaN
# Iter:    25 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   31 Obj: -1.01E+02 Gap:       NaN
# Iter:    26 I:  0 Tm:      0.00 NLPi:    2 Dpth:    8 Lvs:   33 Obj: -1.01E+02 Gap:       NaN
# Iter:    27 I: -1 Tm:      0.00 NLPi:    1 Dpth:    9 Lvs:   32 Obj: -1.01E+02 Gap:       NaN
# Iter:    28 I:  0 Tm:      0.01 NLPi:    3 Dpth:    9 Lvs:   34 Obj: -9.04E+01 Gap:       NaN
# Iter:    29 I:  0 Tm:      0.00 NLPi:    2 Dpth:    9 Lvs:   35 Obj: -1.01E+02 Gap:       NaN
# Iter:    30 I:  0 Tm:      0.01 NLPi:    3 Dpth:   10 Lvs:   37 Obj: -9.04E+01 Gap:       NaN
# Iter:    31 I:  0 Tm:      0.00 NLPi:    2 Dpth:   10 Lvs:   38 Obj: -1.01E+02 Gap:       NaN
# Iter:    32 I:  0 Tm:      0.01 NLPi:    3 Dpth:   11 Lvs:   40 Obj: -9.04E+01 Gap:       NaN
# Iter:    33 I:  0 Tm:      0.00 NLPi:    2 Dpth:   11 Lvs:   41 Obj: -1.01E+02 Gap:       NaN
# Iter:    34 I:  0 Tm:      0.00 NLPi:    3 Dpth:   12 Lvs:   43 Obj: -9.04E+01 Gap:       NaN
# Iter:    35 I:  0 Tm:      0.00 NLPi:    3 Dpth:   12 Lvs:   44 Obj: -1.01E+02 Gap:       NaN
# --Integer Solution:  -1.01E+02 Lowest Leaf:  -1.01E+02 Gap:   0.00E+00
# Iter:    36 I:  0 Tm:      0.00 NLPi:    2 Dpth:   13 Lvs:   44 Obj: -1.01E+02 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :   0.165299999993294      sec
#  Objective      :   -100.750000000000
#  Successful solution
#  ---------------------------------------------------
#
# x1: 1.0
# x2: 0.0
# x3: 1.0
# x4: 0.0
# x5: 0.0
# x6: 0.0
# x7: 0.0
# x8: 1.0
# x9: 1.0
# x10: 0.0
# x11: 0.0
# x12: 0.0
# x13: 0.0
# x14: 0.0
# x15: 0.0
# x16: 0.0
# x17: 0.0
# x18: 0.0
# x19: 0.0
# x20: 0.0
# x21: 0.0
# x22: 0.0
# x23: 0.0
# x24: 0.0
# x25: 0.0
# x26: 0.0
# x27: 0.0
# x28: 0.0
# x29: 0.0
# x30: 0.0
# x31: 0.0
# x32: 0.0
# x33: 0.0
# x34: 0.0
# x35: 0.0
# x36: 0.0
# x37: 0.0
# x38: 0.0
# x39: 0.0
# x40: 0.0
# x41: 0.0
# x42: 0.0
# x43: 0.0
# x44: 0.0
# x45: 0.0
# x46: 0.0
# x47: 0.0
# x48: 0.0
# x49: 0.0
# x50: 0.0
# x51: 0.0
# x52: 0.0
# x53: 0.0
# x54: 0.0
# x55: 0.0
# x56: 0.0
# x57: 0.0
# x58: 0.0
# x59: 0.0
# x60: 0.0
# x61: 0.0
# x62: 0.0
# x63: 0.0
# x64: 0.0
# x65: 0.0
# x66: 0.0
# x67: 0.0
# x68: 0.0
# x69: 0.0
# x70: 0.0
# x71: 0.0
# x72: 0.0
# x73: 0.0
# x74: 0.0
# x75: 0.0
# x76: 0.0
# x77: 0.0
# x78: 0.0
# x79: 0.0
# x80: 0.0
# x81: 0.0
# x82: 0.0
# x83: 0.0
# x84: 0.0
# x85: 0.0
# x86: 0.0
# x87: 0.0
# x88: 0.0
# x89: 0.0
# x90: 0.0
# x91: 0.0
# x92: 0.0
# x93: 0.0
# x94: 0.0
# x95: 0.0
# x96: 0.0
# x97: 0.0
# x98: 0.0
# x99: 0.0
# x100: 0.0
# x101: 1.0
# x102: 0.0
# x103: 1.0
# x104: 0.0
