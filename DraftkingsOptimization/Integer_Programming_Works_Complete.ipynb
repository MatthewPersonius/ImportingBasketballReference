# %%
# !pip install GEKKO
# !pip install ortools

from gekko import GEKKO
# Out:
# Requirement already satisfied: GEKKO in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from GEKKO) (1.20.1)
# Requirement already satisfied: ortools in /opt/anaconda3/lib/python3.8/site-packages (9.0.9048)
# Requirement already satisfied: absl-py>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from ortools) (0.14.0)
# Requirement already satisfied: protobuf>=3.15.8 in /opt/anaconda3/lib/python3.8/site-packages (from ortools) (3.18.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from absl-py>=0.11->ortools) (1.15.0)

# %%
m = GEKKO() # create GEKKO model
# create binary variables
x1 = m.Var(integer=True,lb=0,ub=1) 
x2 = m.Var(integer=True,lb=0,ub=1)
x3 = m.Var(integer=True,lb=0,ub=1)
x4 = m.Var(integer=True,lb=0,ub=1)
x5 = m.Var(integer=True,lb=0,ub=1)
x6 = m.Var(integer=True,lb=0,ub=1)
x7 = m.Var(integer=True,lb=0,ub=1)
x8 = m.Var(integer=True,lb=0,ub=1)
x9 = m.Var(integer=True,lb=0,ub=1)
x10 = m.Var(integer=True,lb=0,ub=1)
x11 = m.Var(integer=True,lb=0,ub=1)
x12 = m.Var(integer=True,lb=0,ub=1)
x13 = m.Var(integer=True,lb=0,ub=1)
x14 = m.Var(integer=True,lb=0,ub=1)
x15 = m.Var(integer=True,lb=0,ub=1)
x16 = m.Var(integer=True,lb=0,ub=1)
x17 = m.Var(integer=True,lb=0,ub=1)
x18 = m.Var(integer=True,lb=0,ub=1)
x19 = m.Var(integer=True,lb=0,ub=1)
x20 = m.Var(integer=True,lb=0,ub=1)
x21 = m.Var(integer=True,lb=0,ub=1)
x22 = m.Var(integer=True,lb=0,ub=1)
x23 = m.Var(integer=True,lb=0,ub=1)
x24 = m.Var(integer=True,lb=0,ub=1)
x25 = m.Var(integer=True,lb=0,ub=1)
x26 = m.Var(integer=True,lb=0,ub=1)
x27 = m.Var(integer=True,lb=0,ub=1)
x28 = m.Var(integer=True,lb=0,ub=1)


m.Equation(x2+x4+x6+x8+x10+x12+x14+x16+x18+x20+x22+x24+x26+x28==1)
m.Equation(x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x11+x12+x13+x14+x15+x16+x17+x18+x19+x20+x21+x22+x23+x24+x25+x26+x27+x28== 6)


m.Equation(x1+x2<=1)
m.Equation(x3+x4<=1)
m.Equation(x5+x6<=1)
m.Equation(x7+x8<=1)
m.Equation(x9+x10<=1)
m.Equation(x11+x12<=1)
m.Equation(x13+x14<=1)
m.Equation(x15+x16<=1)
m.Equation(x17+x18<=1)
m.Equation(x19+x20<=1)
m.Equation(x21+x22<=1)
m.Equation(x23+x24<=1)
m.Equation(x25+x26<=1)
m.Equation(x27+x28<=1)
m.Equation((x1*12200)+(x2*18300)+(x3*10400)+(x4*15900)+(x5*10000)+(x6*15000)+(x7*9600)+
           (x8*14400)+(x9*9200)+(x10*13800)+(x11*8400)+(x12*12600)+(x13*7600)+(x14*11400)+(x15*6800)+
           (x16*10200)+(x17*6200)+(x18*9300)+(x19*5400)+(x20*8100)+(x21*4600)+(x22*6900)+(x23*4200)+(x24*6300)+
           (x25*3800)+(x26*5700)+(x27*3400)+(x28*5100) <=50000)

m.Obj(-((x1*67)+(x2*67*1.5)+(x3*49.7)+(x4*49.7*1.5)+(x5*44.8)+(x6*44.8*1.5)+(x7*48)+(x8*48*1.5)+
                (x9*44.4)+(x10*44.4*1.5)+(x11*43.7)+(x12*43.7*1.5)+(x13*26)+(x14*26*1.5)+(x15*29.3)+
                (x16*29.3*1.5)+(x17*24.2)+(x18*24.2*1.5)+(x19*10.8)+(x20*10.8*1.5)+(x21*14.4)+(x22*14.4*1.5)
                +(x23*22.8)+(x24*22.8*1.5)+(x25*15.9)+(x26*15.9*1.5)+(x27*17.7)+(x28*17.7*1.5)))






m.options.SOLVER = 1 # APOPT solver
m.solve()
print('x1: ' + str(x1.value[0]))
print('x2: ' + str(x2.value[0]))
print('x3: ' + str(x3.value[0]))
print('x4: ' + str(x4.value[0]))
print('x5: ' + str(x5.value[0]))
print('x6: ' + str(x6.value[0]))
print('x7: ' + str(x7.value[0]))
print('x8: ' + str(x8.value[0]))
print('x9: ' + str(x9.value[0]))
print('x10: ' + str(x10.value[0]))
print('x11: ' + str(x11.value[0]))
print('x12: ' + str(x12.value[0]))
print('x13: ' + str(x13.value[0]))
print('x14: ' + str(x14.value[0]))
print('x15: ' + str(x15.value[0]))
print('x16: ' + str(x16.value[0]))
print('x17: ' + str(x17.value[0]))
print('x18: ' + str(x18.value[0]))
print('x19: ' + str(x19.value[0]))
print('x20: ' + str(x20.value[0]))
print('x21: ' + str(x21.value[0]))
print('x22: ' + str(x22.value[0]))
print('x23: ' + str(x23.value[0]))
print('x24: ' + str(x24.value[0]))
print('x25: ' + str(x25.value[0]))
print('x26: ' + str(x26.value[0]))
print('x27: ' + str(x27.value[0]))
print('x28: ' + str(x28.value[0]))
# Out:
# apm 108.183.51.97_gk_model0 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.1
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  Warning: there is insufficient data in CSV file 108.183.51.97_gk_model0.csv
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :           43
#    Intermediates:            0
#    Connections  :            0
#    Equations    :           18
#    Residuals    :           18
#
#  Number of state variables:             43
#  Number of total equations: -           17
#  Number of slack variables: -           15
#  ---------------------------------------
#  Degrees of freedom       :             11
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.00 NLPi:    3 Dpth:    0 Lvs:    3 Obj: -2.61E+02 Gap:       NaN
# --Integer Solution:  -2.49E+02 Lowest Leaf:  -2.61E+02 Gap:   4.77E-02
# Iter:     2 I:  0 Tm:      0.00 NLPi:    2 Dpth:    1 Lvs:    2 Obj: -2.49E+02 Gap:  4.77E-02
# Iter:     3 I:  0 Tm:      0.00 NLPi:    3 Dpth:    1 Lvs:    4 Obj: -2.59E+02 Gap:  4.77E-02
# Iter:     4 I:  0 Tm:      0.00 NLPi:    5 Dpth:    1 Lvs:    6 Obj: -2.60E+02 Gap:  4.77E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.60E+02 Gap:   1.93E-02
# Iter:     5 I:  0 Tm:      0.00 NLPi:    2 Dpth:    2 Lvs:    5 Obj: -2.55E+02 Gap:  1.93E-02
# Iter:     6 I:  0 Tm:      0.00 NLPi:    4 Dpth:    2 Lvs:    7 Obj: -2.57E+02 Gap:  1.93E-02
# Iter:     7 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:    9 Obj: -2.59E+02 Gap:  1.93E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.74E-02
# Iter:     8 I:  0 Tm:      0.00 NLPi:    2 Dpth:    3 Lvs:    8 Obj: -2.55E+02 Gap:  1.74E-02
# Iter:     9 I:  0 Tm:      0.00 NLPi:    4 Dpth:    3 Lvs:   10 Obj: -2.59E+02 Gap:  1.74E-02
# Iter:    10 I:  0 Tm:      0.00 NLPi:    3 Dpth:    3 Lvs:   12 Obj: -2.59E+02 Gap:  1.74E-02
# Iter:    11 I: -1 Tm:      0.00 NLPi:    1 Dpth:    4 Lvs:   11 Obj: -2.59E+02 Gap:  1.74E-02
# Iter:    12 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   13 Obj: -2.59E+02 Gap:  1.74E-02
# Iter:    13 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   15 Obj: -2.59E+02 Gap:  1.74E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.63E-02
# Iter:    14 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:   14 Obj: -2.49E+02 Gap:  1.63E-02
# Iter:    15 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:   16 Obj: -2.58E+02 Gap:  1.63E-02
# Iter:    16 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:   17 Obj: -2.59E+02 Gap:  1.63E-02
# Iter:    17 I:  0 Tm:      0.00 NLPi:    3 Dpth:    3 Lvs:   19 Obj: -2.59E+02 Gap:  1.63E-02
# Iter:    18 I:  0 Tm:      0.00 NLPi:    3 Dpth:    3 Lvs:   21 Obj: -2.57E+02 Gap:  1.63E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.60E-02
# Iter:    19 I:  0 Tm:      0.00 NLPi:    2 Dpth:    4 Lvs:   20 Obj: -2.55E+02 Gap:  1.60E-02
# Iter:    20 I:  0 Tm:      0.00 NLPi:    4 Dpth:    4 Lvs:   22 Obj: -2.58E+02 Gap:  1.60E-02
# Iter:    21 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   24 Obj: -2.59E+02 Gap:  1.60E-02
# Iter:    22 I: -1 Tm:      0.00 NLPi:    1 Dpth:    5 Lvs:   23 Obj: -2.59E+02 Gap:  1.60E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.50E-02
# Iter:    23 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   22 Obj: -2.29E+02 Gap:  1.50E-02
# Iter:    24 I:  0 Tm:      0.00 NLPi:    4 Dpth:    5 Lvs:   24 Obj: -2.58E+02 Gap:  1.50E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.47E-02
# Iter:    25 I:  0 Tm:      0.00 NLPi:    2 Dpth:    5 Lvs:   23 Obj: -2.55E+02 Gap:  1.47E-02
# Iter:    26 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   24 Obj: -2.59E+02 Gap:  1.47E-02
# Iter:    27 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   23 Obj: -2.52E+02 Gap:  1.47E-02
# Iter:    28 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   25 Obj: -2.56E+02 Gap:  1.47E-02
# Iter:    29 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   26 Obj: -2.58E+02 Gap:  1.47E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.40E-02
# Iter:    30 I:  0 Tm:      0.00 NLPi:    2 Dpth:    5 Lvs:   25 Obj: -2.52E+02 Gap:  1.40E-02
# Iter:    31 I:  0 Tm:      0.00 NLPi:    4 Dpth:    5 Lvs:   27 Obj: -2.58E+02 Gap:  1.40E-02
# Iter:    32 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   29 Obj: -2.58E+02 Gap:  1.40E-02
# --Integer Solution:  -2.55E+02 Lowest Leaf:  -2.59E+02 Gap:   1.39E-02
# Iter:    33 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   28 Obj: -2.49E+02 Gap:  1.39E-02
# Iter:    34 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   30 Obj: -2.57E+02 Gap:  1.39E-02
# Iter:    35 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   31 Obj: -2.57E+02 Gap:  1.39E-02
# Iter:    36 I: -1 Tm:      0.00 NLPi:    1 Dpth:    5 Lvs:   30 Obj: -2.58E+02 Gap:  1.39E-02
# Iter:    37 I:  0 Tm:      0.00 NLPi:   13 Dpth:    5 Lvs:   29 Obj: -2.54E+02 Gap:  1.39E-02
# Iter:    38 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   30 Obj: -2.58E+02 Gap:  1.39E-02
# Iter:    39 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   29 Obj: -2.50E+02 Gap:  1.39E-02
# Iter:    40 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   30 Obj: -2.58E+02 Gap:  1.39E-02
# --Integer Solution:  -2.58E+02 Lowest Leaf:  -2.58E+02 Gap:   1.85E-03
# Iter:    41 I:  0 Tm:      0.00 NLPi:    2 Dpth:    6 Lvs:   30 Obj: -2.58E+02 Gap:  1.85E-03
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :   8.670000001438893E-002 sec
#  Objective      :   -257.750000000000
#  Successful solution
#  ---------------------------------------------------
#
# x1: 1.0
# x2: 0.0
# x3: 1.0
# x4: 0.0
# x5: 0.0
# x6: 0.0
# x7: 1.0
# x8: 0.0
# x9: 0.0
# x10: 0.0
# x11: 1.0
# x12: 0.0
# x13: 0.0
# x14: 0.0
# x15: 0.0
# x16: 0.0
# x17: 0.0
# x18: 0.0
# x19: 0.0
# x20: 0.0
# x21: 0.0
# x22: 0.0
# x23: 1.0
# x24: 0.0
# x25: 0.0
# x26: 0.0
# x27: 0.0
# x28: 1.0
